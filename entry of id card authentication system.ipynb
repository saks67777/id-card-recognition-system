# %%
#!pip install opencv-python
#!pip install easyocr

import cv2

import easyocr
list=[]
#import rcParams
print("k")
# Out:
# k

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg # image module for image reading
img = mpimg.imread("C:/D drive data/saket/Music/logos/Test of id card4.PNG")

# %%
plt.imshow(img)

# %%
reader=easyocr.Reader(['en'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
print("k")
# Out:
# k

# %%
output=reader.readtext("C:/D drive data/saket/Music/logos/Test of id card4.PNG")

# %%
print(output)
# Out:
# [([[4, 55], [320, 55], [320, 87], [4, 87]], 'Name: Vishwanathan Anand', 0.8658571673258947), ([[5, 123], [198, 123], [198, 174], [5, 174]], 'Batch: G1', 0.9977700795401231), ([[6, 190], [322, 190], [322, 239], [6, 239]], 'Roll no:1002710', 0.9622806907746527), ([[12, 261], [273, 261], [273, 309], [12, 309]], 'Year:2020-24', 0.908531484076783), ([[10, 342], [324, 342], [324, 396], [10, 396]], 'Blood group: AB', 0.9261044425715333)]

# %%
name1=output[0][1][5:]
batch1=output[1][1][6:]
bloodgroup1=output[4][1][12:]
rno1=output[2][1][8:]
year1=output[3][1][5:]

# %%
from datetime import datetime

# current date and time
now = datetime.now()
#print(now)
tr=str(now)
date_today=tr[:10]
#print(date_today)
time_now=tr[11:19]
import csv
with open('entry_or_exit_time.csv', 'a', newline='') as file:
    writer = csv.writer(file)
    writer.writerow([name1, rno1,batch1,year1,bloodgroup1,date_today,time_now,"entry"])
    print("Entry is given")
# Out:
# Entry is given
